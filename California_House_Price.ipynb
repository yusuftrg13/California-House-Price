# %%
import pandas as pd

# %%
data=pd.read_csv('Desktop/house.csv')

# %%
#California House Price
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
# ...

# %%
#Counting Data
data.count()
# Out:
# longitude             20640
# latitude              20640
# housing_median_age    20640
# total_rooms           20640
# total_bedrooms        20433
# population            20640
# households            20640
# median_income         20640
# ocean_proximity       20640
# median_house_value    20640
# dtype: int64

# %%
#Check the null data
data.isnull()
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0          False     False               False        False           False
# 1          False     False               False        False           False
# 2          False     False               False        False           False
# 3          False     False               False        False           False
# 4          False     False               False        False           False
# ...          ...       ...                 ...          ...             ...
# 20635      False     False               False        False           False
# 20636      False     False               False        False           False
# 20637      False     False               False        False           False
# 20638      False     False               False        False           False
# 20639      False     False               False        False           False
#
# ...

# %%
#Total Null Data
data.isnull().sum()
# Out:
# longitude               0
# latitude                0
# housing_median_age      0
# total_rooms             0
# total_bedrooms        207
# population              0
# households              0
# median_income           0
# ocean_proximity         0
# median_house_value      0
# dtype: int64

# %%
#İmport seaborn library
import seaborn as sns
import matplotlib.pyplot as plt

# %%
#Lets create heatmap for null data
sns.heatmap(data.isnull())
# Out:
# <Axes: >

# %%
#First 20 Data
data.head(20)
# Out:
#     longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0     -122.23     37.88                  41          880           129.0
# 1     -122.22     37.86                  21         7099          1106.0
# 2     -122.24     37.85                  52         1467           190.0
# 3     -122.25     37.85                  52         1274           235.0
# 4     -122.25     37.85                  52         1627           280.0
# 5     -122.25     37.85                  52          919           213.0
# 6     -122.25     37.84                  52         2535           489.0
# 7     -122.25     37.84                  52         3104           687.0
# 8     -122.26     37.84                  42         2555           665.0
# 9     -122.25     37.84                  52         3549           707.0
# 10    -122.26     37.85                  52         2202           434.0
# 11    -122.26     37.85                  52         3503           752.0
# ...

# %%
#End 15 Data
data.tail(15)
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 20625    -121.52     39.12                  37          102            17.0
# 20626    -121.43     39.18                  36         1124           184.0
# 20627    -121.32     39.13                   5          358            65.0
# 20628    -121.48     39.10                  19         2043           421.0
# 20629    -121.39     39.12                  28        10035          1856.0
# 20630    -121.32     39.29                  11         2640           505.0
# 20631    -121.40     39.33                  15         2655           493.0
# 20632    -121.45     39.26                  15         2319           416.0
# 20633    -121.53     39.19                  27         2080           412.0
# 20634    -121.56     39.27                  28         2332           395.0
# 20635    -121.09     39.48                  25         1665           374.0
# ...

# %%
#Check The Dtypes
data.dtypes
# Out:
# longitude             float64
# latitude              float64
# housing_median_age      int64
# total_rooms             int64
# total_bedrooms        float64
# population              int64
# households              int64
# median_income         float64
# ocean_proximity        object
# median_house_value      int64
# dtype: object

# %%
#households remove
data.drop(['households'],axis=1,inplace=True)

# %%
data.head()
# Out:
#    longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0    -122.23     37.88                  41          880           129.0
# 1    -122.22     37.86                  21         7099          1106.0
# 2    -122.24     37.85                  52         1467           190.0
# 3    -122.25     37.85                  52         1274           235.0
# 4    -122.25     37.85                  52         1627           280.0
#
#    population  median_income ocean_proximity  median_house_value
# 0         322         8.3252        NEAR BAY              452600
# 1        2401         8.3014        NEAR BAY              358500
# 2         496         7.2574        NEAR BAY              352100
# 3         558         5.6431        NEAR BAY              341300
# 4         565         3.8462        NEAR BAY              342200

# %%
# Average Home Value Minimum by average home age
data.groupby('housing_median_age').median_house_value.min()
# Out:
# housing_median_age
# 1     55000
# 2     47500
# 3     83200
# 4     42500
# 5     50000
# 6     53200
# 7     56200
# 8     22500
# 9     45000
# 10    37500
# 11    44600
# 12    40000
# 13    43000
# 14    32900
# 15    32500
# 16    14999
# 17    27500
# 18    39200
# 19    14999
# 20    32500
# 21    25000
# 22    34400
# 23    30000
# 24    32500
# 25    45500
# 26    36600
# 27    40000
# 28    40900
# 29    28300
# 30    42500
# 31    34200
# 32    41500
# 33    22500
# 34    26600
# 35    39600
# 36    14999
# 37    42100
# 38    39400
# 39    17500
# 40    43000
# 41    41800
# 42    39400
# 43    46600
# 44    48300
# 45    30000
# 46    26900
# 47    49600
# 48    48600
# 49    52000
# 50    49800
# 51    51900
# 52    14999
# Name: median_house_value, dtype: int64

# %%
#Average Home Value Mean by average home age
data.groupby('housing_median_age').median_house_value.mean()
# Out:
# housing_median_age
# 1     144300.000000
# 2     224475.913793
# 3     235643.580645
# 4     229235.136126
# 5     208417.655738
# 6     203794.393750
# 7     193296.034286
# 8     194414.582524
# 9     186672.702439
# 10    176580.704545
# 11    179907.901575
# 12    182046.235294
# 13    190181.807947
# 14    189597.104369
# 15    181808.416016
# 16    200180.562905
# 17    190494.289398
# 18    193354.766667
# 19    193197.838645
# 20    195659.815054
# 21    200156.535874
# 22    209897.558897
# 23    204554.741071
# 24    205833.098326
# 25    220414.180212
# 26    209475.316640
# 27    208296.973361
# 28    208158.866242
# 29    197227.800434
# 30    200252.560924
# 31    207084.117904
# 32    203410.141593
# 33    203628.175610
# 34    214593.962264
# 35    207298.950243
# 36    207573.943155
# 37    207360.772812
# 38    193593.695431
# 39    208890.560976
# 40    208918.483553
# 41    197253.773649
# 42    198772.603261
# 43    193639.135977
# 44    216233.471910
# ...

# %%
#Total Statistics Values
data.describe()
# Out:
#           longitude      latitude  housing_median_age   total_rooms  \
# count  20640.000000  20640.000000        20640.000000  20640.000000
# mean    -119.569704     35.631861           28.639486   2635.763081
# std        2.003532      2.135952           12.585558   2181.615252
# min     -124.350000     32.540000            1.000000      2.000000
# 25%     -121.800000     33.930000           18.000000   1447.750000
# 50%     -118.490000     34.260000           29.000000   2127.000000
# 75%     -118.010000     37.710000           37.000000   3148.000000
# max     -114.310000     41.950000           52.000000  39320.000000
#
#        total_bedrooms    population  median_income  median_house_value
# count    20433.000000  20640.000000   20640.000000        20640.000000
# mean       537.870553   1425.476744       3.870671       206855.816909
# std        421.385070   1132.462122       1.899822       115395.615874
# min          1.000000      3.000000       0.499900        14999.000000
# ...

# %%
#Correlation relationships
data.corr()
# Out:
# C:\Users\Casper\AppData\Local\Temp\ipykernel_12836\2627137660.py:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   data.corr()
#                     longitude  latitude  housing_median_age  total_rooms  \
# longitude            1.000000 -0.924664           -0.108197     0.044568
# latitude            -0.924664  1.000000            0.011173    -0.036100
# housing_median_age  -0.108197  0.011173            1.000000    -0.361262
# total_rooms          0.044568 -0.036100           -0.361262     1.000000
# total_bedrooms       0.069608 -0.066983           -0.320451     0.930380
# population           0.099773 -0.108785           -0.296244     0.857126
# median_income       -0.015176 -0.079809           -0.119034     0.198050
# median_house_value  -0.045967 -0.144160            0.105623     0.134153
#
# ...

# %%
#Histogram Chart
data.hist(figsize=(20,10))
# Out:
# array([[<Axes: title={'center': 'longitude'}>,
#         <Axes: title={'center': 'latitude'}>,
#         <Axes: title={'center': 'housing_median_age'}>],
#        [<Axes: title={'center': 'total_rooms'}>,
#         <Axes: title={'center': 'total_bedrooms'}>,
#         <Axes: title={'center': 'population'}>],
#        [<Axes: title={'center': 'median_income'}>,
#         <Axes: title={'center': 'median_house_value'}>, <Axes: >]],
#       dtype=object)

# %%
#Check Data
data
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 0        -122.23     37.88                  41          880           129.0
# 1        -122.22     37.86                  21         7099          1106.0
# 2        -122.24     37.85                  52         1467           190.0
# 3        -122.25     37.85                  52         1274           235.0
# 4        -122.25     37.85                  52         1627           280.0
# ...          ...       ...                 ...          ...             ...
# 20635    -121.09     39.48                  25         1665           374.0
# 20636    -121.21     39.49                  18          697           150.0
# 20637    -121.22     39.43                  17         2254           485.0
# 20638    -121.32     39.43                  18         1860           409.0
# 20639    -121.24     39.37                  16         2785           616.0
#
# ...

# %%
#Scatter Chart 
#Relationship between population and total rooms
data.plot(kind='scatter',x='population',y='total_rooms')
# Out:
# <Axes: xlabel='population', ylabel='total_rooms'>

# %%
#Is there a relationship between income and household age?
data.plot(kind='hist',x='housing_median_age',y='median_income',alpha=0.5,bins=10)
# Out:
# <Axes: ylabel='Frequency'>

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 20640 entries, 0 to 20639
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   longitude           20640 non-null  float64
#  1   latitude            20640 non-null  float64
#  2   housing_median_age  20640 non-null  int64
#  3   total_rooms         20640 non-null  int64
#  4   total_bedrooms      20433 non-null  float64
#  5   population          20640 non-null  int64
#  6   median_income       20640 non-null  float64
#  7   ocean_proximity     20640 non-null  object
#  8   median_house_value  20640 non-null  int64
# dtypes: float64(4), int64(4), object(1)
# memory usage: 1.4+ MB

# %%
data.sort_values(by=['housing_median_age','median_house_value'])
# Out:
#        longitude  latitude  housing_median_age  total_rooms  total_bedrooms  \
# 12286    -116.95     33.86                   1            6             2.0
# 3130     -117.95     35.08                   1           83            15.0
# 19536    -120.93     37.65                   1         2254           328.0
# 18972    -122.00     38.23                   1         2062           343.0
# 2774     -115.80     33.26                   2           96            18.0
# ...          ...       ...                 ...          ...             ...
# 18338    -122.15     37.44                  52         1945           293.0
# 18339    -122.14     37.44                  52         3117           468.0
# 18340    -122.14     37.43                  52         1944           308.0
# 18341    -122.14     37.43                  52         1327           190.0
# 18342    -122.14     37.43                  52         1383           227.0
#
# ...
